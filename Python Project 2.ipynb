# %% [markdown]
# # E-Commerce – EDA – Python Project 2

# %% [markdown]
# Context of Data
#  Company - UK-based and registered non-store online retail
#  Products for selling - Mainly all-occasion gifts
#  Customers - Most are wholesalers (local or international)
#  Transactions Period - 1st Dec 2010 - 9th Dec 2011 (One year)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("D:/PYTHON ALL/Python Project 2/Ecommerce - UK Retailer.csv", encoding= 'unicode_escape')

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.shape
# Out:
# (541909, 8)

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#         InvoiceDate  UnitPrice  CustomerID         Country
# 0  12-01-2010 08:26       2.55     17850.0  United Kingdom
# 1  12-01-2010 08:26       3.39     17850.0  United Kingdom
# 2  12-01-2010 08:26       2.75     17850.0  United Kingdom
# 3  12-01-2010 08:26       3.39     17850.0  United Kingdom
# 4  12-01-2010 08:26       3.39     17850.0  United Kingdom

# %%
df.tail()
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID Country
# 541904  12-09-2011 12:50       0.85     12680.0  France
# 541905  12-09-2011 12:50       2.10     12680.0  France
# 541906  12-09-2011 12:50       4.15     12680.0  France
# 541907  12-09-2011 12:50       4.15     12680.0  France
# 541908  12-09-2011 12:50       4.95     12680.0  France

# %% [markdown]
# # 2. Check for missing values in all columns and replace them with the appropriate metric (Mean/Median/Mode)

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df[df["Description"].isna()]
# Out:
#        InvoiceNo StockCode Description  Quantity       InvoiceDate  UnitPrice  \
# 622       536414     22139         NaN        56  12-01-2010 11:52        0.0
# 1970      536545     21134         NaN         1  12-01-2010 14:32        0.0
# 1971      536546     22145         NaN         1  12-01-2010 14:33        0.0
# 1972      536547     37509         NaN         1  12-01-2010 14:33        0.0
# 1987      536549    85226A         NaN         1  12-01-2010 14:34        0.0
# ...          ...       ...         ...       ...               ...        ...
# 535322    581199     84581         NaN        -2  12-07-2011 18:26        0.0
# 535326    581203     23406         NaN        15  12-07-2011 18:31        0.0
# 535332    581209     21620         NaN         6  12-07-2011 18:35        0.0
# 536981    581234     72817         NaN        27  12-08-2011 10:33        0.0
# 538554    581408     85175         NaN        20  12-08-2011 14:06        0.0
#
# ...

# %%
df["Description"].replace(np.NaN, df["Description"].mode()[0], inplace=True)

# %%
df["Description"].mode()
# Out:
# 0    WHITE HANGING HEART T-LIGHT HOLDER
# dtype: object

# %%
df[df["Description"].isna()]
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %%
df[df["CustomerID"].isna()]
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 622       536414     22139  WHITE HANGING HEART T-LIGHT HOLDER        56
# 1443      536544     21773     DECORATIVE ROSE BATHROOM BOTTLE         1
# 1444      536544     21774     DECORATIVE CATS BATHROOM BOTTLE         2
# 1445      536544     21786                  POLKADOT RAIN HAT          4
# 1446      536544     21787               RAIN PONCHO RETROSPOT         2
# ...          ...       ...                                 ...       ...
# 541536    581498    85099B             JUMBO BAG RED RETROSPOT         5
# 541537    581498    85099C      JUMBO  BAG BAROQUE BLACK WHITE         4
# 541538    581498     85150       LADIES & GENTLEMEN METAL SIGN         1
# 541539    581498     85174                   S/4 CACTI CANDLES         1
# 541540    581498       DOT                      DOTCOM POSTAGE         1
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df["CustomerID"].mode()
# Out:
# 0    17841.0
# dtype: float64

# %%
df["CustomerID"].replace(np.NaN, df["CustomerID"].mode()[0], inplace=True)

# %%
df[df["CustomerID"].isna()]
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %%
df.isna().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %% [markdown]
# # 3. Remove duplicate rows

# %%
df.duplicated().sum()
# Out:
# 5268

# %%
df = df.drop_duplicates()
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.shape
# Out:
# (536641, 8)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # 4. Remove rows which have negative values in Quantity column

# %%
a= df[df["Quantity"]<0]
a
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df=df[df["Quantity"]>0]
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df[df["Quantity"]<0]
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %%
df[df["UnitPrice"]<0]
# Out:
#        InvoiceNo StockCode      Description  Quantity       InvoiceDate  \
# 299983   A563186         B  Adjust bad debt         1  08-12-2011 14:51
# 299984   A563187         B  Adjust bad debt         1  08-12-2011 14:52
#
#         UnitPrice  CustomerID         Country
# 299983  -11062.06     17841.0  United Kingdom
# 299984  -11062.06     17841.0  United Kingdom

# %%
df=df[df["UnitPrice"]>0]
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df[df["UnitPrice"]<0]
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %%
df["Amount_spent"]=df["Quantity"]*df["UnitPrice"]
df
# Out:
# C:\Users\mohsin\AppData\Local\Temp/ipykernel_15828/1783853272.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Amount_spent"]=df["Quantity"]*df["UnitPrice"]
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 524878 entries, 0 to 541908
# Data columns (total 9 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   InvoiceNo     524878 non-null  object
#  1   StockCode     524878 non-null  object
#  2   Description   524878 non-null  object
#  3   Quantity      524878 non-null  int64
#  4   InvoiceDate   524878 non-null  object
#  5   UnitPrice     524878 non-null  float64
#  6   CustomerID    524878 non-null  float64
#  7   Country       524878 non-null  object
#  8   Amount_spent  524878 non-null  float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 40.0+ MB

# %% [markdown]
# # 1. Perform Basic EDA

# %% [markdown]
# ## a. Boxplot – All Numeric Variables

# %%
fig, ax = plt.subplots(nrows = 2, ncols = 2, figsize = (10,10))
df['Quantity'].plot(kind = "box" , ax = ax[0,0])
ax[0,0].set_title("Outliers in Quantity")
df['UnitPrice'].plot(kind = "box" , ax = ax[0,1])
ax[0,1].set_title("Outliers in UnitPrice")
df['Amount_spent'].plot(kind = "box" ,ax = ax[1,0])
ax[1,0].set_title("Outliers in Amount_spent")
df['CustomerID'].plot(kind = "box" , ax = ax[1,1])
ax[1,1].set_title("CustomerIDs")
plt.show()

# %% [markdown]
# ## b. Histogram – All Numeric Variables

# %%
sns.displot(df['Quantity'].unique(), bins = 10 )
plt.show()

# %%
sns.displot(df['UnitPrice'].unique(), bins = 5 )
plt.show()

# %%
sns.displot(df['Amount_spent'].unique(), bins = 5 )
plt.show()

# %% [markdown]
# ## c. Distribution Plot – All Numeric Variables

# %% [markdown]
# ### Distribution plot is same as histogram

# %% [markdown]
# ## d. Aggregation for all numerical Columns

# %%
df["Quantity"].sum()
# Out:
# 5572420

# %%
df["UnitPrice"].sum()
# Out:
# 2058872.0440000005

# %%
df["Amount_spent"].sum()
# Out:
# 10642110.804

# %% [markdown]
# ## e. Unique Values across all columns

# %%
df.nunique()
# Out:
# InvoiceNo       19960
# StockCode        3922
# Description      4026
# Quantity          375
# InvoiceDate     18499
# UnitPrice        1291
# CustomerID       4338
# Country            38
# Amount_spent     4906
# dtype: int64

# %% [markdown]
# ## f. Duplicate values across all columns

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## g. Correlation – Heatmap - All Numeric Variables

# %%
df.corr()
# Out:
#               Quantity  UnitPrice  CustomerID  Amount_spent
# Quantity      1.000000  -0.003788   -0.021356      0.907402
# UnitPrice    -0.003788   1.000000    0.018172      0.137381
# CustomerID   -0.021356   0.018172    1.000000     -0.012042
# Amount_spent  0.907402   0.137381   -0.012042      1.000000

# %% [markdown]
# ### Heatmap using Correlation

# %%
sns.heatmap(data=df.corr(), annot=True)
plt.show()

# %% [markdown]
# ## h. Regression Plot - All Numeric Variables

# %%
sns.regplot(x = "UnitPrice", y = "Quantity", data = df)
plt.show()

# %%
sns.regplot(x = "Amount_spent", y = "UnitPrice", data = df)
plt.show()

# %%
sns.regplot(x = "Quantity", y = "Amount_spent", data = df)
plt.show()

# %% [markdown]
# ## i. Bar Plot – Every Categorical Variable vs every Numerical Variable

# %%
plt.figure (figsize = (20,10))
plt.xticks(rotation=90)
sns.barplot(data = df, x = "Country", y = "Quantity")
plt.title("Country vs Quantity")
plt.show()

# %%
plt.figure (figsize = (20,10))
plt.xticks(rotation=90)
sns.barplot(data = df, x = "Country", y = "Amount_spent")
plt.title("Country vs Amount Spent")
plt.show()

# %% [markdown]
# ## j. Pair plot - All Numeric Variables

# %%
plt.figure (figsize = (20,7))
sns.pairplot(df[:10000])
plt.show()

# %% [markdown]
# ## k. Line chart to show the trend of data - All Numeric/Date Variables

# %%
plt.figure(figsize = (20,7))
sns.lineplot(data = df["Quantity"].unique())
plt.show()

# %%
plt.figure (figsize = (20,7))
sns.lineplot(data = df["Amount_spent"].unique())
plt.show()

# %% [markdown]
# ## l. Plot the skewness - All Numeric Variables

# %%
df["Quantity"].skew()
# Out:
# 469.54178476684893

# %%
df["UnitPrice"].skew()
# Out:
# 205.08516799804903

# %%
df["Amount_spent"].skew()
# Out:
# 504.23256211676784

# %% [markdown]
# # 5. Add the columns - Month, Day and Hour for the invoice

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country  Amount_spent
# ...

# %%
df['InvoiceDate'] = pd.to_datetime(df.InvoiceDate)
# Out:
# C:\Users\mohsin\AppData\Local\Temp/ipykernel_15828/527658872.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['InvoiceDate'] = pd.to_datetime(df.InvoiceDate)

# %%
df.insert(loc=2, column='Year_month', value=df['InvoiceDate'].map(lambda x: 100*x.year + x.month))
df.insert(loc=3, column='month', value=df.InvoiceDate.dt.month)
df.insert(loc=4, column='day', value=(df.InvoiceDate.dt.dayofweek)+1)
df.insert(loc=5, column='hour', value=df.InvoiceDate.dt.hour)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 524878 entries, 0 to 541908
# Data columns (total 13 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   InvoiceNo     524878 non-null  object
#  1   StockCode     524878 non-null  object
#  2   Year_month    524878 non-null  int64
#  3   month         524878 non-null  int64
#  4   day           524878 non-null  int64
#  5   hour          524878 non-null  int64
#  6   Description   524878 non-null  object
#  7   Quantity      524878 non-null  int64
#  8   InvoiceDate   524878 non-null  datetime64[ns]
#  9   UnitPrice     524878 non-null  float64
#  10  CustomerID    524878 non-null  float64
#  11  Country       524878 non-null  object
#  12  Amount_spent  524878 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(5), object(4)
# memory usage: 72.2+ MB

# %% [markdown]
# # 6. How many orders made by the customers?

# %%
orders = df.groupby(by=['CustomerID','Country'], as_index=False)['InvoiceNo'].count()
plt.subplots(figsize=(15,6))
plt.plot(orders.CustomerID, orders.InvoiceNo)
plt.xlabel('Customers ID')
plt.ylabel('Number of Orders')
plt.title('Number of Orders for different Customers')
plt.show()

# %%
orders.count()
# Out:
# CustomerID    4354
# Country       4354
# InvoiceNo     4354
# dtype: int64

# %% [markdown]
# # 7. TOP 5 customers with higher number of orders

# %%
orders.sort_values(by='InvoiceNo', ascending=False).head()
# Out:
#       CustomerID         Country  InvoiceNo
# 4025     17841.0  United Kingdom     138458
# 1887     14911.0            EIRE       5670
# 1297     14096.0  United Kingdom       5111
# 334      12748.0  United Kingdom       4412
# 1669     14606.0  United Kingdom       2677

# %% [markdown]
# # 8. How much money spent by the customers?

# %%
money_spent = df.groupby(by=['CustomerID','Country'], as_index=False)['Amount_spent'].sum()
plt.subplots(figsize=(15,6))
plt.plot(money_spent.CustomerID, money_spent.Amount_spent)
plt.xlabel('Customers ID')
plt.ylabel('Money spent (Dollar)')
plt.title('Money Spent for different Customers')
plt.show()

# %%
df["Amount_spent"].sum()
# Out:
# 10642110.804

# %% [markdown]
# # 9. TOP 5 customers with highest money spent

# %%
money_spent.sort_values(by="Amount_spent", ascending= False).head()
# Out:
#       CustomerID         Country  Amount_spent
# 4025     17841.0  United Kingdom    1757239.29
# 1697     14646.0     Netherlands     280206.02
# 4217     18102.0  United Kingdom     259657.30
# 3736     17450.0  United Kingdom     194390.79
# 3016     16446.0  United Kingdom     168472.50

# %% [markdown]
# # 10. How many orders per month?

# %%
print(df.groupby('InvoiceNo')['month'].unique().value_counts().sort_index())
# Out:
# [1]     1086
# [2]     1100
# [3]     1454
# [4]     1246
# [5]     1681
# [6]     1533
# [7]     1475
# [8]     1361
# [9]     1837
# [10]    2040
# [11]    2769
# [12]    2378
# Name: month, dtype: int64

# %%
ax = df.groupby('InvoiceNo')['Year_month'].unique().value_counts().sort_index().plot(kind = 'bar',figsize=(15,6))
ax.set_xlabel('Month',fontsize=15)
ax.set_ylabel('Number of Orders',fontsize=15)
ax.set_title('Number of orders for different Months (1st Dec 2010 - 9th Dec 2011)',fontsize=15)
ax.set_xticklabels(('Dec_10','Jan_11','Feb_11','Mar_11','Apr_11','May_11','Jun_11','July_11','Aug_11','Sep_11','Oct_11','Nov_11','Dec_11'), rotation='horizontal', fontsize=13)
plt.show()

# %% [markdown]
# # 11. How many orders per day?

# %%
x = df.groupby('InvoiceNo')['day'].unique().value_counts().sort_index().plot(kind = 'bar',figsize=(15,6))
x.set_xlabel('Day',fontsize=15)
x.set_ylabel('Number of Orders',fontsize=15)
x.set_title('Number of orders for different Days',fontsize=15)
x.set_xticklabels(('Mon','Tue','Wed','Thur','Fri','Sun'), rotation='horizontal', fontsize=15)
plt.show()

# %%
print(df.groupby('InvoiceNo')['day'].unique().value_counts().sort_index())
# Out:
# [1]    3126
# [2]    3554
# [3]    3690
# [4]    4246
# [5]    3140
# [7]    2204
# Name: day, dtype: int64

# %% [markdown]
# # 12. How many orders per hour?

# %%
x = df.groupby('InvoiceNo')['hour'].unique().value_counts().iloc[:-1].plot(kind = 'bar',figsize=(15,6))
x.set_xlabel('Hour',fontsize=15)
x.set_ylabel('Number of Orders',fontsize=15)
x.set_title('Number of orders for different Hours',fontsize=15)
x.set_xticklabels(range(6,21), rotation='horizontal', fontsize=15)
plt.show()

# %%
print(df.groupby('InvoiceNo')['hour'].unique().value_counts())
# Out:
# [12]        3219
# [13]        2753
# [14]        2457
# [11]        2395
# [10]        2361
# [15]        2336
# [9]         1484
# [16]        1335
# [17]         667
# [8]          566
# [18]         192
# [19]         146
# [7]           29
# [20]          18
# [11, 12]       1
# [6]            1
# Name: hour, dtype: int64

# %% [markdown]
# # 13. How many orders for each country?

# %%
country_orders = df.groupby('Country')['InvoiceNo'].count().sort_values()
plt.subplots(figsize=(15,8))
country_orders.plot(kind = 'bar', fontsize=12)
plt.xlabel('Number of Orders', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.title('Number of Orders for different Countries', fontsize=12)
plt.show()

# %%
country_orders = df.groupby('Country')['InvoiceNo'].count().sort_values()
del country_orders['United Kingdom']
plt.subplots(figsize=(15,8))
country_orders.plot(kind = 'bar', fontsize=12)
plt.xlabel('Number of Orders', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.title('Number of Orders for different Countries', fontsize=12)
plt.show()

# %% [markdown]
# # 14. Orders trend across months

# %%
x = df.groupby('InvoiceNo')['month'].unique().value_counts().sort_values().plot(kind = 'bar',figsize=(15,6))
x.set_xlabel('Month',fontsize=15)
x.set_ylabel('Number of Orders',fontsize=15)
x.set_title('Number of orders for different Months',fontsize=15)
x.set_xticklabels(('January','February','March','April','May','June','July','August','September','October','November','December'), rotation=90, fontsize=15)
plt.show()

# %%
print(df.groupby('InvoiceNo')['month'].unique().value_counts().sort_values())
# Out:
# [1]     1086
# [2]     1100
# [4]     1246
# [8]     1361
# [3]     1454
# [7]     1475
# [6]     1533
# [5]     1681
# [9]     1837
# [10]    2040
# [12]    2378
# [11]    2769
# Name: month, dtype: int64

# %% [markdown]
# # 15. How much money spent by each country?

# %%
country_amount_spent = df.groupby('Country')['Amount_spent'].sum().sort_values()
plt.subplots(figsize=(15,8))
country_amount_spent.plot(kind = 'bar', fontsize=12)
plt.xlabel('Money Spent ($)', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.title('Money Spent by different Countries', fontsize=12)
plt.show()

# %%
country_amount_spent = df.groupby('Country')['Amount_spent'].sum().sort_values()
del country_amount_spent['United Kingdom']
plt.subplots(figsize=(15,8))
country_amount_spent.plot(kind = 'bar', fontsize=12)
plt.xlabel('Money Spent ($)', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.title('Money Spent by different Countries', fontsize=12)
plt.show()
